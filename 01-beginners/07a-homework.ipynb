# %% [markdown]
# # Алгоритмы и структуры данных в Python
#
# ## Занятие 7: Домашнее задание

# %% [markdown]
# 1. Имеются 2 списка целых чисел, упорядоченные по возрастанию. Получите новый список, содержащий все элементы исходных списков, в котором элементы также упорядочены в порядке возрастания, не используя сортировку.

# %%
# ваш код здесь

# %% [markdown]
# 2. Имеется список названий месяцев: ```['января', 'февраля', 'марта', 'апреля', 'мая', 'июня', 'июля', 'августа', 'сентября', 'октября', 'ноября', 'декабря']```. Создайте по этому списку словарь, в котором название месяца будет ключом, а номер месяца (от 1 до 12) – значением. Напишите функцию, которая, используя полученный словарь преобразует строку с датой вида «1 января 2016» в строку «1.01.2016». Получите ввод пользователя и выведите на экран результат работы функции.
#
# __ПОДСКАЗКА__ для разбиентя строки используйте метод ```split()``` (например, ```"a b".split(' ')``` вернет список ```['a', 'b']```)

# %%
months_ = ['января', 'февраля', 'марта', 'апреля', 'мая', 'июня', \
           'июля', 'августа', 'сентября', 'октября', 'ноября', 'декабря']
dict_ = {}

def formatter(str_date: string):
    pass
    # ваш код здесь
    
# и здесь

# %% [markdown]
# 3. Вводится целое число. Напишите функцию, которая дописывает с к нему слова «рубль», «рубля» или «рублей» в зависимости от значения. Алгоритм:
# - исключение: если число оканчивается на 11, 12, 13 или 14, добавляем слово «рублей»;
# - если число оканчивается на 1, добавляем слово «рубль»;
# - если число оканчивается на 2, 3 или 4, добавляем слово «рубля»;
# - если число оканчивается на цифры 5, 6, 7, 8, 9 или 0, добавляем слово «рублей».
#
# Функция должна возвращать только дописываемое значение.
#
# Выведите указанную сумму и результат работы функции на экран.

# %%
num = input("Введите целое число: ")

def roubles(num: int):
    # ваш код здесь
    pass

# ваш код здесь

# %% [markdown]
# 4. Задан список с вложенными списками (элементы - числа). Для всех списков с длиной больше 3: оставить только три первых элемента, прибавив к третьему все удаленные элементы. Например, из ```[[1,2], [3,4,4,3,1], [4,1,4,5]]``` получить ```[[1, 2], [3, 4, 8], [4, 1, 9]]```.

# %%
list_of_lists = [[1,2], [3,4,4,3,1], [4,1,4,5]]

# ваш код здесь

# %% [markdown]
# 5. Реализуйте функцию которая выполняет операции сложения или умножения над неограниченным количеством аргументов.
# Первым аргументов функция должна принимать название операции "sum" или "mul", затем - остальные аргументы, которые надо сложить или перемножить друг на друга.
#
# Написать примеры использования этой функции, с аргументами, приведенными ниже

# %%
a1 = (15, 10 ,5)
a2 = (3, 1)
a3 = [2, 35, 55]
a4 = (5, 10 ,15, 20)

def sum_mul(operation: str, *args):
    pass
    # ваш код здесь
    
print(sum_mul('mul', *a1))
